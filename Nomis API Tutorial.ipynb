# %% [markdown]
# # Nomis API Tutorial
#
# This is a tutorial on accessing data from the NOMIS API. Nomis is a service provided by the Office for National Statistics, ONS, to give you free access to the most detailed and up-to-date UK labour market statistics from official sources.
#
# https://www.nomisweb.co.uk/api/v01/help

# %%
import requests as rq
import pandas as pd
from fuzzywuzzy import fuzz

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Listing all data in NOMIS
#
# Data sets in NOMIS have an ID, name, and description which are useful parameters to use when searching for different data sets. NOMIS stores this uesful information in objects it calls "key families". We can build a function that will get the ID, name, and description of all the data sets in NOMIS so that we can search them locally on our computer.

# %%
def list_data_sets():
    
    # This function obtains a list of all the NOMIS datasets available
    
    # Make the request to the API
    root = "http://www.nomisweb.co.uk"
    ext = "/api/v01/dataset/def.sdmx.json"
    response = rq.get(root + ext).json()
    
    # Process the response to get the useful info from the key families if it is available
    keyFams = response['structure']['keyfamilies']['keyfamily']
    data_sets = []
    meta_data = {}
    for keyFam in keyFams:

        row = {}
        
        try:
            row['description'] = keyFam['description']['value']         
        except:
            pass
            

        try:
            row['id'] = keyFam['id']
            meta_data[keyFam['id']] = {}
        except:
            pass
            

        try:
            row['name'] = keyFam['name']['value']       
        except:
            pass
        
        
        data_sets.append(row)
           
            
        try:
            annotations = keyFam['annotations']['annotation']
            for anotation in annotations:
                meta_data[keyFam['id']][anotation['annotationtitle']] = anotation['annotationtext']
        except:
            pass

        
        try:
            components = keyFam['components']
            meta_data[keyFam['id']]['dimensions'] = []
            for dimension in components['dimension']:
                meta_data[keyFam['id']]['dimensions'].append(dimension['conceptref'])

            meta_data[keyFam['id']]['primarymeasure'] = components['primarymeasure']['conceptref']
            meta_data[keyFam['id']]['timedimension'] = components['timedimension']['conceptref']
        except:
            pass

                    
    return data_sets, meta_data

# %%
data_sets, meta_data = list_data_sets()
df_data_sets_list = pd.DataFrame(data_sets)
df_data_sets_list.head()
# Out:
#                                                                                                                                                                                                                                                                    description  \
# 0  Records the number of people claiming Jobseeker's Allowance (JSA) and National Insurance credits at Jobcentre Plus local offices. This is not an official measure of unemployment, but is the only indicative statistic available for areas smaller than Local Authorities.
# 1                                                                                                                                              A quartery count of claimants who were claiming Jobseeker's Allowance on the count date analysed by their age and the duration.
# 2                                                     A monthly count of Jobseeker's Allowance (JSA) claimants broken down by age and the duration of claim. Totals exclude non-computerised clerical claims (approx. 1%). Available for areas smaller than Local Authorities.
# 3                                                                                           A midyear estimate of the workforce (the denominator) which was used for calculating claimant count rates prior to January 2003. The estimates are broken down by sex but not age.
# 4                                                                                                                                                                         A quarterly count of  Jobseeker's Allowance claimants analysed by their sought and usual occupation.
#
#        id                                                       name
# 0  NM_1_1           Jobseeker's Allowance with rates and proportions
# 1  NM_2_1                          claimant count - age and duration
# 2  NM_4_1                  Jobseeker's Allowance by age and duration
# 3  NM_5_1  claimant count denominators - historical workforce series
# 4  NM_6_1                                claimant count - occupation

# %% [markdown]
# # Searching the list of data sets
#
# We can search for data on different topics by looking in the list of data sets for key words. We can search either the id, the description, or the name. We can build a function to do help with this.

# %%
def search_data_list(df_data_sets_list, search_field, search_term):
    
    # This function will search a filed (e.g., id, description or name) to see 
    # how well it matches the terms in the search_term
    # Results are returned in a table with the best matches at the top
    
    df = df_data_sets_list.copy()
    df['search_score'] = df[search_field].apply(lambda x: fuzz.token_sort_ratio(x, search_term))
    df = df.sort_values('search_score', ascending=False)
    
    return df

# %%
df_search_results = search_data_list(df_data_sets_list, 'name', 'unemploy')
df_search_results.head(20)
# Out:
#                                                                                                                                                                                                                                                                                                              description  \
# 96                                                                                                                                                                                                                                                                                                                   NaN
# 166                                                                                                                                                                                                                                                                                                                  NaN
# 244                                                                                                                                                                                                                                                                                                                  NaN
# 951                                                                                                                                                                                                                                                                                                                  NaN
# 11    A residence based labour market survey encompassing population, economic activity (employment and unemployment), economic inactivity and qualifications. These are broken down where possible by gender, age, ethnicity, industry and occupation. Available at Local Authority level and above. Updated quarterly.
# 97                                                                                                                                                                                                                                                                                                                   NaN
# 241                                                                                                                                                                                                                                                                                                                  NaN
# 527                                                                                                                                                                                                                                                                                                                  NaN
# 1022                                                                                                                                                                                                                                                                                                                 NaN
# 952                                                                                                                                                                                                                                                                                                                  NaN
# 953                                                                                                                                                                                                                                                                                                                  NaN
# 877                                                                                                                                                                                                                                                                                                                  NaN
# 891                                                                                                                                                                                                                                                                                                                  NaN
# 173                                                                                                                                                                                                                                                                                                                  NaN
# 982                                                                                                                                                                                                                                                                                                                  NaN
# 945                                                                                                                                                                                                                                                                                                                  NaN
# 525                                                                                                                                                                                                                                                                                                                  NaN
# 894                                                                                                                                                                                                                                                                                                                  NaN
# 61         A monthly count of claimants who either a) were claiming benefit (stocks, flow=1) on the count date; this count is the same as that in USJ, B)  ceased to be unemployed (off-flows, flow=2) during the previous accounting month, c) became claimants (on-flows, flow=3) during the previous accounting month
# 245                                                                                                                                                                                                                                                                                                                  NaN
#
#              id                                       name  search_score
# 96     NM_127_1      model-based estimates of unemployment            36
# 166    NM_509_1                                 Population            33
# 244    NM_589_1                                 Occupation            33
# 951   NM_1613_1            KS011a - Industry of employment            32
# 11      NM_17_1                   annual population survey            31
# 97     NM_129_1     Annual Civil Service Employment Survey            30
# 241    NM_586_1                Economic Position - Females            30
# 527    NM_918_1                     ST606EWla - Occupation            29
# 1022  NM_1684_1                     UV068 - Household type            29
# 952   NM_1614_1    KS011b - Industry of employment - males            28
# 953   NM_1615_1  KS011c - Industry of employment - females            27
# 877   NM_1507_1                           KS402UK - Tenure            27
# 891   NM_1521_1                           KS611UK - NS-SeC            27
# 173    NM_516_1                   QS116EW - Household type            27
# 982   NM_1644_1                           UV015 - Religion            27
# 945   NM_1607_1                           KS007 - Religion            27
# 525    NM_916_1                   ST604EWla - Hours worked            27
# 894   NM_1530_1                   QS101UK - Residence type            27
# 61      NM_85_1                             claimant flows            27
# 245    NM_590_1                             Qualifications            27

# %% [markdown]
# ## Checking which dimensions are available on a particular data set

# %%
meta_data['NM_127_1']
# Out:
# {'Status': 'Current (being actively updated)',
#  'Units': 'Persons',
#  'contenttype/sources': 'aps',
#  'SubDescription': 'previously unavailable',
#  'Mnemonic': 'umb',
#  'FirstReleased': '2006-03-29 09:30:00',
#  'LastUpdated': '2019-07-16 09:30:00',
#  'LastRevised': '2019-04-16 09:30:00',
#  'dimensions': ['GEOGRAPHY', 'ITEM', 'MEASURES', 'FREQ'],
#  'primarymeasure': 'OBS_VALUE',
#  'timedimension': 'TIME'}

# %%
def dimension_values(data_set_id, dimension):
    
    root = "http://www.nomisweb.co.uk"
    ext = f'/api/v01/dataset/{data_set_id}/{dimension}.def.sdmx.json'
    response = rq.get(root + ext).json()
    dim_vals = [
        {
            'description': item['description']['value'],
            'value': item['value'],
            'dimension': dimension
        } for item in response['structure']['codelists']['codelist'][0]['code']
    ]
    return dim_vals


def all_dimension_values(meta_data, data_set_id):
    
    # This function gets the values that are available for different dimensions on a data set
    
    dimensions = meta_data[data_set_id]['dimensions']
    all_dim_vals = []
    for dimension in dimensions:
        all_dim_vals += dimension_values(data_set_id, dimension)
        
    return all_dim_vals

# %%
pd.DataFrame(all_dimension_values(meta_data, 'NM_127_1'))
# Out:
#                          description       value  dimension
# 0                      Great Britain  2092957698  GEOGRAPHY
# 1                            England  2092957699  GEOGRAPHY
# 2                              Wales  2092957700  GEOGRAPHY
# 3                           Scotland  2092957701  GEOGRAPHY
# 4                  England and Wales  2092957703  GEOGRAPHY
# 5   Unemployment count (model based)           1       ITEM
# 6    Unemployment rate (model based)           2       ITEM
# 7                              value       20100   MEASURES
# 8                         confidence       20701   MEASURES
# 9                          Quarterly           Q       FREQ
# 10             Half-yearly, semester           S       FREQ
# 11                          Annually           A       FREQ

# %% [markdown]
# # Available geography levels for a data set

# %%
pd.DataFrame(dimension_values('NM_127_1', 'geography/2092957699')).head(100)
# Out:
#                                                                   description  \
# 0                                                                     England
# 1       local authorities: county / unitary (as of April 2021) within England
# 2     local authorities: district / unitary (as of April 2021) within England
# 3     local authorities: district / unitary (as of April 2019) within England
# 4                                         combined authorities within England
# 5             local enterprise partnerships (as of April 2021) within England
# 6    local authorities: county / unitary (prior to April 2015) within England
# 7  local authorities: district / unitary (prior to April 2015) within England
# 8                                             english counties within England
# 9                                                      regions within England
#
#                value             dimension
# 0         2092957699  geography/2092957699
# 1  2092957699TYPE431  geography/2092957699
# 2  2092957699TYPE432  geography/2092957699
# 3  2092957699TYPE434  geography/2092957699
# 4  2092957699TYPE442  geography/2092957699
# 5  2092957699TYPE459  geography/2092957699
# 6  2092957699TYPE463  geography/2092957699
# 7  2092957699TYPE464  geography/2092957699
# 8  2092957699TYPE469  geography/2092957699
# 9  2092957699TYPE480  geography/2092957699

# %%
pd.DataFrame(dimension_values('NM_127_1', 'geography/2092957699TYPE432')).head(100)
# Out:
#                     description       value                    dimension
# 0                    Darlington  1811939329  geography/2092957699TYPE432
# 1                 County Durham  1811939330  geography/2092957699TYPE432
# 2                    Hartlepool  1811939331  geography/2092957699TYPE432
# 3                 Middlesbrough  1811939332  geography/2092957699TYPE432
# 4                Northumberland  1811939334  geography/2092957699TYPE432
# 5          Redcar and Cleveland  1811939335  geography/2092957699TYPE432
# 6              Stockton-on-Tees  1811939336  geography/2092957699TYPE432
# 7                     Gateshead  1811939338  geography/2092957699TYPE432
# 8           Newcastle upon Tyne  1811939339  geography/2092957699TYPE432
# 9                North Tyneside  1811939340  geography/2092957699TYPE432
# 10               South Tyneside  1811939341  geography/2092957699TYPE432
# 11                   Sunderland  1811939342  geography/2092957699TYPE432
# 12        Blackburn with Darwen  1811939343  geography/2092957699TYPE432
# 13                    Blackpool  1811939344  geography/2092957699TYPE432
# 14                Cheshire East  1811939345  geography/2092957699TYPE432
# 15    Cheshire West and Chester  1811939346  geography/2092957699TYPE432
# 16                       Halton  1811939347  geography/2092957699TYPE432
# 17                   Warrington  1811939348  geography/2092957699TYPE432
# 18                    Allerdale  1811939349  geography/2092957699TYPE432
# 19            Barrow-in-Furness  1811939350  geography/2092957699TYPE432
# 20                     Carlisle  1811939351  geography/2092957699TYPE432
# 21                     Copeland  1811939352  geography/2092957699TYPE432
# 22                         Eden  1811939353  geography/2092957699TYPE432
# 23               South Lakeland  1811939354  geography/2092957699TYPE432
# 24                       Bolton  1811939355  geography/2092957699TYPE432
# 25                         Bury  1811939356  geography/2092957699TYPE432
# 26                   Manchester  1811939357  geography/2092957699TYPE432
# 27                       Oldham  1811939358  geography/2092957699TYPE432
# 28                     Rochdale  1811939359  geography/2092957699TYPE432
# 29                      Salford  1811939360  geography/2092957699TYPE432
# 30                    Stockport  1811939361  geography/2092957699TYPE432
# 31                     Tameside  1811939362  geography/2092957699TYPE432
# 32                     Trafford  1811939363  geography/2092957699TYPE432
# 33                        Wigan  1811939364  geography/2092957699TYPE432
# 34                      Burnley  1811939365  geography/2092957699TYPE432
# 35                      Chorley  1811939366  geography/2092957699TYPE432
# 36                        Fylde  1811939367  geography/2092957699TYPE432
# 37                     Hyndburn  1811939368  geography/2092957699TYPE432
# 38                    Lancaster  1811939369  geography/2092957699TYPE432
# 39                       Pendle  1811939370  geography/2092957699TYPE432
# 40                      Preston  1811939371  geography/2092957699TYPE432
# 41                Ribble Valley  1811939372  geography/2092957699TYPE432
# 42                   Rossendale  1811939373  geography/2092957699TYPE432
# 43                 South Ribble  1811939374  geography/2092957699TYPE432
# 44              West Lancashire  1811939375  geography/2092957699TYPE432
# 45                         Wyre  1811939376  geography/2092957699TYPE432
# 46                     Knowsley  1811939377  geography/2092957699TYPE432
# 47                    Liverpool  1811939378  geography/2092957699TYPE432
# 48                       Sefton  1811939379  geography/2092957699TYPE432
# 49                   St. Helens  1811939380  geography/2092957699TYPE432
# 50                       Wirral  1811939381  geography/2092957699TYPE432
# 51     East Riding of Yorkshire  1811939382  geography/2092957699TYPE432
# 52  Kingston upon Hull, City of  1811939383  geography/2092957699TYPE432
# 53      North East Lincolnshire  1811939384  geography/2092957699TYPE432
# 54           North Lincolnshire  1811939385  geography/2092957699TYPE432
# 55                         York  1811939386  geography/2092957699TYPE432
# 56                       Craven  1811939387  geography/2092957699TYPE432
# 57                    Hambleton  1811939388  geography/2092957699TYPE432
# 58                    Harrogate  1811939389  geography/2092957699TYPE432
# 59                Richmondshire  1811939390  geography/2092957699TYPE432
# 60                      Ryedale  1811939391  geography/2092957699TYPE432
# 61                  Scarborough  1811939392  geography/2092957699TYPE432
# 62                        Selby  1811939393  geography/2092957699TYPE432
# 63                     Barnsley  1811939394  geography/2092957699TYPE432
# 64                    Doncaster  1811939395  geography/2092957699TYPE432
# 65                    Rotherham  1811939396  geography/2092957699TYPE432
# 66                    Sheffield  1811939397  geography/2092957699TYPE432
# 67                     Bradford  1811939398  geography/2092957699TYPE432
# 68                   Calderdale  1811939399  geography/2092957699TYPE432
# 69                     Kirklees  1811939400  geography/2092957699TYPE432
# 70                        Leeds  1811939401  geography/2092957699TYPE432
# 71                    Wakefield  1811939402  geography/2092957699TYPE432
# 72                        Derby  1811939403  geography/2092957699TYPE432
# 73                    Leicester  1811939404  geography/2092957699TYPE432
# 74                   Nottingham  1811939405  geography/2092957699TYPE432
# 75                      Rutland  1811939406  geography/2092957699TYPE432
# 76                 Amber Valley  1811939407  geography/2092957699TYPE432
# 77                     Bolsover  1811939408  geography/2092957699TYPE432
# 78                 Chesterfield  1811939409  geography/2092957699TYPE432
# 79             Derbyshire Dales  1811939410  geography/2092957699TYPE432
# 80                      Erewash  1811939411  geography/2092957699TYPE432
# 81                    High Peak  1811939412  geography/2092957699TYPE432
# 82        North East Derbyshire  1811939413  geography/2092957699TYPE432
# 83             South Derbyshire  1811939414  geography/2092957699TYPE432
# 84                        Blaby  1811939415  geography/2092957699TYPE432
# 85                    Charnwood  1811939416  geography/2092957699TYPE432
# 86                   Harborough  1811939417  geography/2092957699TYPE432
# 87        Hinckley and Bosworth  1811939418  geography/2092957699TYPE432
# 88                       Melton  1811939419  geography/2092957699TYPE432
# 89    North West Leicestershire  1811939420  geography/2092957699TYPE432
# 90            Oadby and Wigston  1811939421  geography/2092957699TYPE432
# 91                       Boston  1811939422  geography/2092957699TYPE432
# 92                 East Lindsey  1811939423  geography/2092957699TYPE432
# 93                      Lincoln  1811939424  geography/2092957699TYPE432
# 94               North Kesteven  1811939425  geography/2092957699TYPE432
# 95                South Holland  1811939426  geography/2092957699TYPE432
# 96               South Kesteven  1811939427  geography/2092957699TYPE432
# 97                 West Lindsey  1811939428  geography/2092957699TYPE432
# 98                     Ashfield  1811939436  geography/2092957699TYPE432
# 99                    Bassetlaw  1811939437  geography/2092957699TYPE432

# %% [markdown]
# ## Available time periods for a data set
#
# Time/date info from nomis API docs.
# Useful time options:
#  - "latest" - the latest available data for this dataset
#  - "previous" - the date prior to "latest"
#  - "prevyear" - the date one year prior to "latest"
#  - "first" - the oldest available data for this dataset
#
# Using the "time" concept you are limited to entering two dates, a start and end. All dates between these are returned.
#
# Date is more flexible for range. With the "date" parameter you can specify relative dates, so for example if you wanted the latest date, three months and six months prior to that you could specify "date=latest,latestMINUS3,latestMINUS6".
# You can use ranges with the "date" parameter, e.g. if you wanted data for 12 months ago, together with all dates in the last six month up to latest you could specify "date=prevyear,latestMINUS5-latest". To illustrate the difference between using "date" and "time"; if you specified "time=first,latest" in your URI you would get all dates from first to latest inclusive, whereas with "date=first,latest" your output would contain only the first and latest dates.

# %%
pd.DataFrame(dimension_values('NM_127_1', 'time')).head(100)
# Out:
#           description    value dimension
# 0   Jan 2004-Dec 2004  2004-12      time
# 1   Apr 2004-Mar 2005  2005-03      time
# ## Downloading a data set
#
# To get a data set from the NOMIS API we put together a query. A query is a string that contains the information on the data we are requesting such as the dataset id, the gegraphical area, and the time period. We can define a function to build the query string based on this information and then pass the query string to pandas to request the data.

# %%
def make_query(data_set_id, dimension_filters={}):
    
    # This function makes a query string for requesting data from the NOMIS API
    
    root = "http://www.nomisweb.co.uk"
    ext = "/api/v01/dataset/"
    
    params = '&'.join([f'{dimension.lower()}={dimension_filters[dimension]}' for dimension in dimension_filters.keys()])
    if len(params) > 0:
        params = f'?{params}'
        
    query = f'{root}{ext}{data_set_id}.data.csv{params}'

    return query

# %%
dimension_filters = {
    'GEOGRAPHY': '2092957699TYPE432',
    'MEASURES': '20100',
    'TIME': '2020-12,2019-12,2018-12',
    'ITEM': '1'
}

query_string = make_query('NM_127_1', dimension_filters)
query_string
# Out:
# 'http://www.nomisweb.co.uk/api/v01/dataset/NM_127_1.data.csv?geography=2092957699TYPE432&measures=20100&time=2020-12,2019-12,2018-12&item=1'

# %%
df = pd.read_csv(query_string)

# %%
df.shape
# Out:
# (2781, 28)

# %%
df.columns
# Out:
# Index(['DATE', 'DATE_NAME', 'DATE_CODE', 'DATE_TYPE', 'DATE_TYPECODE',
#        'DATE_SORTORDER', 'GEOGRAPHY', 'GEOGRAPHY_NAME', 'GEOGRAPHY_CODE',
#        'GEOGRAPHY_TYPE', 'GEOGRAPHY_TYPECODE', 'GEOGRAPHY_SORTORDER', 'ITEM',
#        'ITEM_NAME', 'ITEM_CODE', 'ITEM_TYPE', 'ITEM_TYPECODE',
#        'ITEM_SORTORDER', 'MEASURES', 'MEASURES_NAME', 'OBS_VALUE',
#        'OBS_STATUS', 'OBS_STATUS_NAME', 'OBS_CONF', 'OBS_CONF_NAME', 'URN',
#        'RECORD_OFFSET', 'RECORD_COUNT'],
#       dtype='object')

# %%
df.head(100)
# Out:
#        DATE          DATE_NAME DATE_CODE DATE_TYPE  DATE_TYPECODE  \
# 0   2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 1   2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 2   2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 3   2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 4   2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 5   2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 6   2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 7   2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 8   2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 9   2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 10  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 11  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 12  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 13  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 14  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 15  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 16  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 17  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 18  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 19  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 20  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 21  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 22  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 23  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 24  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 25  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 26  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 27  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 28  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 29  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 30  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 31  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 32  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 33  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 34  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 35  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 36  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 37  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 38  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 39  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 40  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 41  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 42  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 43  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 44  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 45  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 46  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 47  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 48  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 49  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 50  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 51  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 52  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 53  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 54  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 55  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 56  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 57  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 58  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 59  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 60  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 61  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 62  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 63  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 64  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 65  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 66  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 67  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 68  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 69  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 70  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 71  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 72  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 73  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 74  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 75  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 76  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 77  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 78  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 79  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 80  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 81  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 82  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 83  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 84  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 85  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 86  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 87  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 88  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 89  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 90  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 91  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 92  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 93  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 94  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 95  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 96  2018-12  Jan 2018-Dec 2018   2018-12      date              0
# 97  2018-12  Jan 2018-Dec 2018   2018-12      date              0
#
# 8                  432                    8     1
# 9                  432                    9     1
# 10                 432                   10     1
# 11                 432                   11     1
# 12                 432                   12     1
# 13                 432                   13     1
# 14                 432                   14     1
# 15                 432                   15     1
# 16                 432                   16     1
# 17                 432                   17     1
# 18                 432                   18     1
# 19                 432                   19     1
# 20                 432                   20     1
# 21                 432                   21     1
# 22                 432                   22     1
# 23                 432                   23     1
# 24                 432                   24     1
# 25                 432                   25     1
# 26                 432                   26     1
# 27                 432                   27     1
# 28                 432                   28     1
# 29                 432                   29     1
# 30                 432                   30     1
# 31                 432                   31     1
# 32                 432                   32     1
# 33                 432                   33     1
# 34                 432                   34     1
# 35                 432                   35     1
# 36                 432                   36     1
# 37                 432                   37     1
# 38                 432                   38     1
# 39                 432                   39     1
# 40                 432                   40     1
# 41                 432                   41     1
# 42                 432                   42     1
# 43                 432                   43     1
# 44                 432                   44     1
# 45                 432                   45     1
# 46                 432                   46     1
# 47                 432                   47     1
# 48                 432                   48     1
# 49                 432                   49     1
# 50                 432                   50     1
# 51                 432                   51     1
# 52                 432                   52     1
# 53                 432                   53     1
# 54                 432                   54     1
# 55                 432                   55     1
# 56                 432                   56     1
# 57                 432                   57     1
# 58                 432                   58     1
# 59                 432                   59     1
# 60                 432                   60     1
# 61                 432                   61     1
# 62                 432                   62     1
# 63                 432                   63     1
# 64                 432                   64     1
# 65                 432                   65     1
# 66                 432                   66     1
# 67                 432                   67     1
# 68                 432                   68     1
# 69                 432                   69     1
# 70                 432                   70     1
# 71                 432                   71     1
# 72                 432                   72     1
# 73                 432                   73     1
# 74                 432                   74     1
# 75                 432                   75     1
# 76                 432                   76     1
# 77                 432                   77     1
# 78                 432                   78     1
# 79                 432                   79     1
# 80                 432                   80     1
# 81                 432                   81     1
# 82                 432                   82     1
# 83                 432                   83     1
# 84                 432                   84     1
# 85                 432                   85     1
# 86                 432                   86     1
# 87                 432                   87     1
# 88                 432                   88     1
# 89                 432                   89     1
# 90                 432                   90     1
# 91                 432                   91     1
# 92                 432                   92     1
# 93                 432                   93     1
# 94                 432                   94     1
# 95                 432                   95     1
# 96                 432                   96     1
# 97                 432                   97     1
# 98                 432                   98     1
# 99                 432                   99     1
#
#                            ITEM_NAME  ITEM_CODE ITEM_TYPE  ITEM_TYPECODE  \
# 0   Unemployment count (model based)          1      item              0
# 1   Unemployment count (model based)          1      item              0
# 2   Unemployment count (model based)          1      item              0
# 3   Unemployment count (model based)          1      item              0
# 4   Unemployment count (model based)          1      item              0
# 5   Unemployment count (model based)          1      item              0
# 6   Unemployment count (model based)          1      item              0
# 7   Unemployment count (model based)          1      item              0
# 8   Unemployment count (model based)          1      item              0
# 9   Unemployment count (model based)          1      item              0
# 10  Unemployment count (model based)          1      item              0
# 11  Unemployment count (model based)          1      item              0
# 12  Unemployment count (model based)          1      item              0
# 13  Unemployment count (model based)          1      item              0
# 14  Unemployment count (model based)          1      item              0
# 15  Unemployment count (model based)          1      item              0
# 16  Unemployment count (model based)          1      item              0
# 17  Unemployment count (model based)          1      item              0
# 18  Unemployment count (model based)          1      item              0
# 19  Unemployment count (model based)          1      item              0
# 20  Unemployment count (model based)          1      item              0
# 21  Unemployment count (model based)          1      item              0
# 22  Unemployment count (model based)          1      item              0
# 23  Unemployment count (model based)          1      item              0
# 24  Unemployment count (model based)          1      item              0
# 25  Unemployment count (model based)          1      item              0
# 26  Unemployment count (model based)          1      item              0
# 27  Unemployment count (model based)          1      item              0
# 28  Unemployment count (model based)          1      item              0
# 29  Unemployment count (model based)          1      item              0
# 30  Unemployment count (model based)          1      item              0
# 31  Unemployment count (model based)          1      item              0
# 32  Unemployment count (model based)          1      item              0
# 33  Unemployment count (model based)          1      item              0
# 34  Unemployment count (model based)          1      item              0
# 35  Unemployment count (model based)          1      item              0
# 36  Unemployment count (model based)          1      item              0
# 37  Unemployment count (model based)          1      item              0
# 38  Unemployment count (model based)          1      item              0
# 39  Unemployment count (model based)          1      item              0
# 40  Unemployment count (model based)          1      item              0
# 41  Unemployment count (model based)          1      item              0
# 42  Unemployment count (model based)          1      item              0
# 43  Unemployment count (model based)          1      item              0
# 44  Unemployment count (model based)          1      item              0
# 45  Unemployment count (model based)          1      item              0
# 46  Unemployment count (model based)          1      item              0
# 47  Unemployment count (model based)          1      item              0
# 48  Unemployment count (model based)          1      item              0
# 49  Unemployment count (model based)          1      item              0
# 50  Unemployment count (model based)          1      item              0
# 51  Unemployment count (model based)          1      item              0
# 52  Unemployment count (model based)          1      item              0
# 53  Unemployment count (model based)          1      item              0
# 54  Unemployment count (model based)          1      item              0
# 55  Unemployment count (model based)          1      item              0
# 56  Unemployment count (model based)          1      item              0
# 57  Unemployment count (model based)          1      item              0
# 58  Unemployment count (model based)          1      item              0
# 59  Unemployment count (model based)          1      item              0
# 60  Unemployment count (model based)          1      item              0
# 61  Unemployment count (model based)          1      item              0
# 62  Unemployment count (model based)          1      item              0
# 63  Unemployment count (model based)          1      item              0
# 64  Unemployment count (model based)          1      item              0
# 65  Unemployment count (model based)          1      item              0
# 66  Unemployment count (model based)          1      item              0
# 67  Unemployment count (model based)          1      item              0
# 68  Unemployment count (model based)          1      item              0
# 69  Unemployment count (model based)          1      item              0
# 70  Unemployment count (model based)          1      item              0
# 71  Unemployment count (model based)          1      item              0
# 72  Unemployment count (model based)          1      item              0
# 73  Unemployment count (model based)          1      item              0
# 74  Unemployment count (model based)          1      item              0
# 75  Unemployment count (model based)          1      item              0
# 76  Unemployment count (model based)          1      item              0
# 77  Unemployment count (model based)          1      item              0
# 78  Unemployment count (model based)          1      item              0
# 79  Unemployment count (model based)          1      item              0
# 80  Unemployment count (model based)          1      item              0
# 81  Unemployment count (model based)          1      item              0
# 82  Unemployment count (model based)          1      item              0
# 83  Unemployment count (model based)          1      item              0
# 84  Unemployment count (model based)          1      item              0
# 85  Unemployment count (model based)          1      item              0
# 86  Unemployment count (model based)          1      item              0
# 87  Unemployment count (model based)          1      item              0
# 88  Unemployment count (model based)          1      item              0
# 89  Unemployment count (model based)          1      item              0
# 90  Unemployment count (model based)          1      item              0
# 91  Unemployment count (model based)          1      item              0
# 92  Unemployment count (model based)          1      item              0
# 93  Unemployment count (model based)          1      item              0
# 94  Unemployment count (model based)          1      item              0
# 95  Unemployment count (model based)          1      item              0
# 96  Unemployment count (model based)          1      item              0
# 97  Unemployment count (model based)          1      item              0
# 98  Unemployment count (model based)          1      item              0
# 99  Unemployment count (model based)          1      item              0
#
#     ITEM_SORTORDER  MEASURES MEASURES_NAME  OBS_VALUE OBS_STATUS  \
# 0                0     20100         Value     2500.0          A
# 1                0     20100         Value    12200.0          A
# 2                0     20100         Value     3700.0          A
# 3                0     20100         Value     4500.0          A
# 4                0     20100         Value     6300.0          A
# 5                0     20100         Value     3200.0          A
# 6                0     20100         Value     5200.0          A
# 7                0     20100         Value     4800.0          A
# 8                0     20100         Value     8000.0          A
# 9                0     20100         Value     4700.0          A
# 10               0     20100         Value     4500.0          A
# 11               0     20100         Value     8200.0          A
# 12               0     20100         Value     3500.0          A
# 13               0     20100         Value     3600.0          A
# 14               0     20100         Value     6000.0          A
# 15               0     20100         Value     6100.0          A
# 16               0     20100         Value     2800.0          A
# 17               0     20100         Value     4200.0          A
# 18               0     20100         Value     1500.0          A
# 19               0     20100         Value     1400.0          A
# 20               0     20100         Value     1400.0          A
# 21               0     20100         Value     1300.0          A
# 22               0     20100         Value      500.0          A
# 23               0     20100         Value      900.0          A
# 24               0     20100         Value     6500.0          A
# 25               0     20100         Value     3700.0          A
# 26               0     20100         Value    14900.0          A
# 27               0     20100         Value     5600.0          A
# 28               0     20100         Value     5200.0          A
# 29               0     20100         Value     6800.0          A
# 30               0     20100         Value     4600.0          A
# 31               0     20100         Value     5300.0          A
# 32               0     20100         Value     4300.0          A
# 33               0     20100         Value     6600.0          A
# 34               0     20100         Value     2300.0          A
# 35               0     20100         Value     1800.0          A
# 36               0     20100         Value      900.0          A
# 37               0     20100         Value     1800.0          A
# 38               0     20100         Value     3400.0          A
# 39               0     20100         Value     1800.0          A
# 40               0     20100         Value     3300.0          A
# 41               0     20100         Value      700.0          A
# 42               0     20100         Value     1500.0          A
# 43               0     20100         Value     2000.0          A
# 44               0     20100         Value     2300.0          A
# 45               0     20100         Value     1600.0          A
# 46               0     20100         Value     2500.0          A
# 47               0     20100         Value     9600.0          A
# 48               0     20100         Value     4100.0          A
# 49               0     20100         Value     2900.0          A
# 50               0     20100         Value     4200.0          A
# 51               0     20100         Value     5400.0          A
# 52               0     20100         Value     7800.0          A
# 53               0     20100         Value     4400.0          A
# 54               0     20100         Value     4300.0          A
# 55               0     20100         Value     3500.0          A
# 56               0     20100         Value      800.0          A
# 57               0     20100         Value     1300.0          A
# 58               0     20100         Value     2600.0          A
# 59               0     20100         Value      800.0          A
# 60               0     20100         Value      700.0          A
# 61               0     20100         Value     1700.0          A
# 62               0     20100         Value     1400.0          A
# 63               0     20100         Value     5900.0          A
# 64               0     20100         Value     8300.0          A
# 65               0     20100         Value     6100.0          A
# 66               0     20100         Value    14400.0          A
# 67               0     20100         Value    11700.0          A
# 68               0     20100         Value     4400.0          A
# 69               0     20100         Value    10300.0          A
# 70               0     20100         Value    16300.0          A
# 71               0     20100         Value     8100.0          A
# 72               0     20100         Value     5900.0          A
# 73               0     20100         Value     9300.0          A
# 74               0     20100         Value    10900.0          A
# 75               0     20100         Value      600.0          A
# 76               0     20100         Value     2500.0          A
# 77               0     20100         Value     1900.0          A
# 78               0     20100         Value     2700.0          A
# 79               0     20100         Value     1100.0          A
# 80               0     20100         Value     3000.0          A
# 81               0     20100         Value     1800.0          A
# 82               0     20100         Value     2000.0          A
# 83               0     20100         Value     1800.0          A
# 84               0     20100         Value     1800.0          A
# 85               0     20100         Value     3800.0          A
# 86               0     20100         Value     1600.0          A
# 87               0     20100         Value     2200.0          A
# 88               0     20100         Value     1100.0          A
# 89               0     20100         Value     2100.0          A
# 90               0     20100         Value     1000.0          A
# 91               0     20100         Value     1400.0          A
# 92               0     20100         Value     2700.0          A
# 93               0     20100         Value     3200.0          A
# 94               0     20100         Value     2000.0          A
# 95               0     20100         Value     1800.0          A
# 96               0     20100         Value     2900.0          A
# 97               0     20100         Value     2100.0          A
# 98               0     20100         Value     3000.0          A
# 99               0     20100         Value     2800.0          A
#
#    OBS_STATUS_NAME OBS_CONF                OBS_CONF_NAME  \
# 0     Normal Value        F  Free (free for publication)
# 1     Normal Value        F  Free (free for publication)
# 2     Normal Value        F  Free (free for publication)
# 3     Normal Value        F  Free (free for publication)
# 4     Normal Value        F  Free (free for publication)
# 5     Normal Value        F  Free (free for publication)
# 6     Normal Value        F  Free (free for publication)
# 7     Normal Value        F  Free (free for publication)
# 8     Normal Value        F  Free (free for publication)
# 9     Normal Value        F  Free (free for publication)
# 10    Normal Value        F  Free (free for publication)
# 11    Normal Value        F  Free (free for publication)
# 12    Normal Value        F  Free (free for publication)
# 13    Normal Value        F  Free (free for publication)
# 14    Normal Value        F  Free (free for publication)
# 15    Normal Value        F  Free (free for publication)
# 16    Normal Value        F  Free (free for publication)
# 17    Normal Value        F  Free (free for publication)
# 18    Normal Value        F  Free (free for publication)
# 19    Normal Value        F  Free (free for publication)
# 20    Normal Value        F  Free (free for publication)
# 21    Normal Value        F  Free (free for publication)
# 22    Normal Value        F  Free (free for publication)
# 23    Normal Value        F  Free (free for publication)
# 24    Normal Value        F  Free (free for publication)
# 25    Normal Value        F  Free (free for publication)
# 26    Normal Value        F  Free (free for publication)
# 27    Normal Value        F  Free (free for publication)
# 28    Normal Value        F  Free (free for publication)
# 29    Normal Value        F  Free (free for publication)
# 30    Normal Value        F  Free (free for publication)
# 31    Normal Value        F  Free (free for publication)
# 32    Normal Value        F  Free (free for publication)
# 33    Normal Value        F  Free (free for publication)
# 34    Normal Value        F  Free (free for publication)
# 35    Normal Value        F  Free (free for publication)
# 36    Normal Value        F  Free (free for publication)
# 37    Normal Value        F  Free (free for publication)
# 38    Normal Value        F  Free (free for publication)
# 39    Normal Value        F  Free (free for publication)
# 40    Normal Value        F  Free (free for publication)
# 41    Normal Value        F  Free (free for publication)
# 42    Normal Value        F  Free (free for publication)
# 43    Normal Value        F  Free (free for publication)
# 44    Normal Value        F  Free (free for publication)
# 45    Normal Value        F  Free (free for publication)
# 46    Normal Value        F  Free (free for publication)
# 47    Normal Value        F  Free (free for publication)
# 48    Normal Value        F  Free (free for publication)
# 49    Normal Value        F  Free (free for publication)
# 50    Normal Value        F  Free (free for publication)
# 51    Normal Value        F  Free (free for publication)
# 52    Normal Value        F  Free (free for publication)
# 53    Normal Value        F  Free (free for publication)
# 54    Normal Value        F  Free (free for publication)
# 55    Normal Value        F  Free (free for publication)
# 56    Normal Value        F  Free (free for publication)
# 57    Normal Value        F  Free (free for publication)
# 58    Normal Value        F  Free (free for publication)
# 59    Normal Value        F  Free (free for publication)
# 60    Normal Value        F  Free (free for publication)
# 61    Normal Value        F  Free (free for publication)
# 62    Normal Value        F  Free (free for publication)
# 63    Normal Value        F  Free (free for publication)
# 64    Normal Value        F  Free (free for publication)
# 65    Normal Value        F  Free (free for publication)
# 66    Normal Value        F  Free (free for publication)
# 67    Normal Value        F  Free (free for publication)
# 68    Normal Value        F  Free (free for publication)
# 69    Normal Value        F  Free (free for publication)
# 70    Normal Value        F  Free (free for publication)
# 71    Normal Value        F  Free (free for publication)
# 72    Normal Value        F  Free (free for publication)
# 73    Normal Value        F  Free (free for publication)
# 74    Normal Value        F  Free (free for publication)
# 75    Normal Value        F  Free (free for publication)
# 76    Normal Value        F  Free (free for publication)
# 77    Normal Value        F  Free (free for publication)
# 78    Normal Value        F  Free (free for publication)
# 79    Normal Value        F  Free (free for publication)
# 80    Normal Value        F  Free (free for publication)
# 81    Normal Value        F  Free (free for publication)
# 82    Normal Value        F  Free (free for publication)
# 83    Normal Value        F  Free (free for publication)
# 84    Normal Value        F  Free (free for publication)
# 85    Normal Value        F  Free (free for publication)
# 86    Normal Value        F  Free (free for publication)
# 87    Normal Value        F  Free (free for publication)
# 88    Normal Value        F  Free (free for publication)
# 89    Normal Value        F  Free (free for publication)
# 90    Normal Value        F  Free (free for publication)
# 91    Normal Value        F  Free (free for publication)
# 92    Normal Value        F  Free (free for publication)
# 93    Normal Value        F  Free (free for publication)
# 94    Normal Value        F  Free (free for publication)
# 95    Normal Value        F  Free (free for publication)
# 96    Normal Value        F  Free (free for publication)
# 97    Normal Value        F  Free (free for publication)
# 98    Normal Value        F  Free (free for publication)
# 99    Normal Value        F  Free (free for publication)
#
#                                     URN  RECORD_OFFSET  RECORD_COUNT
# 0   Nm-127d1d32300e0d1811939329d1d20100              0          2781
# 1   Nm-127d1d32300e0d1811939330d1d20100              1          2781
# 2   Nm-127d1d32300e0d1811939331d1d20100              2          2781
# 3   Nm-127d1d32300e0d1811939332d1d20100              3          2781
# 4   Nm-127d1d32300e0d1811939334d1d20100              4          2781
# 5   Nm-127d1d32300e0d1811939335d1d20100              5          2781
# 6   Nm-127d1d32300e0d1811939336d1d20100              6          2781
# 7   Nm-127d1d32300e0d1811939338d1d20100              7          2781
# 8   Nm-127d1d32300e0d1811939339d1d20100              8          2781
# 9   Nm-127d1d32300e0d1811939340d1d20100              9          2781
# 10  Nm-127d1d32300e0d1811939341d1d20100             10          2781
# 11  Nm-127d1d32300e0d1811939342d1d20100             11          2781
# 12  Nm-127d1d32300e0d1811939343d1d20100             12          2781
# 13  Nm-127d1d32300e0d1811939344d1d20100             13          2781
# 14  Nm-127d1d32300e0d1811939345d1d20100             14          2781
# 15  Nm-127d1d32300e0d1811939346d1d20100             15          2781
# 65  Nm-127d1d32300e0d1811939396d1d20100             65          2781
# 66  Nm-127d1d32300e0d1811939397d1d20100             66          2781
# 67  Nm-127d1d32300e0d1811939398d1d20100             67          2781
# 68  Nm-127d1d32300e0d1811939399d1d20100             68          2781
# 69  Nm-127d1d32300e0d1811939400d1d20100             69          2781
# 70  Nm-127d1d32300e0d1811939401d1d20100             70          2781
# 71  Nm-127d1d32300e0d1811939402d1d20100             71          2781
# 72  Nm-127d1d32300e0d1811939403d1d20100             72          2781
# 73  Nm-127d1d32300e0d1811939404d1d20100             73          2781
# 74  Nm-127d1d32300e0d1811939405d1d20100             74          2781
# 75  Nm-127d1d32300e0d1811939406d1d20100             75          2781
# 76  Nm-127d1d32300e0d1811939407d1d20100             76          2781
# 77  Nm-127d1d32300e0d1811939408d1d20100             77          2781
# 78  Nm-127d1d32300e0d1811939409d1d20100             78          2781
# 79  Nm-127d1d32300e0d1811939410d1d20100             79          2781
# 80  Nm-127d1d32300e0d1811939411d1d20100             80          2781
# 81  Nm-127d1d32300e0d1811939412d1d20100             81          2781
# 82  Nm-127d1d32300e0d1811939413d1d20100             82          2781
# 83  Nm-127d1d32300e0d1811939414d1d20100             83          2781
# 84  Nm-127d1d32300e0d1811939415d1d20100             84          2781
# 85  Nm-127d1d32300e0d1811939416d1d20100             85          2781
# 86  Nm-127d1d32300e0d1811939417d1d20100             86          2781
# 87  Nm-127d1d32300e0d1811939418d1d20100             87          2781
# 88  Nm-127d1d32300e0d1811939419d1d20100             88          2781
# 89  Nm-127d1d32300e0d1811939420d1d20100             89          2781
# 90  Nm-127d1d32300e0d1811939421d1d20100             90          2781
# 91  Nm-127d1d32300e0d1811939422d1d20100             91          2781
# 92  Nm-127d1d32300e0d1811939423d1d20100             92          2781
# 93  Nm-127d1d32300e0d1811939424d1d20100             93          2781
# 94  Nm-127d1d32300e0d1811939425d1d20100             94          2781
# 95  Nm-127d1d32300e0d1811939426d1d20100             95          2781
# 96  Nm-127d1d32300e0d1811939427d1d20100             96          2781
# 97  Nm-127d1d32300e0d1811939428d1d20100             97          2781
# 98  Nm-127d1d32300e0d1811939436d1d20100             98          2781
# 99  Nm-127d1d32300e0d1811939437d1d20100             99          2781

# %%
len(set(df.GEOGRAPHY))
# Out:
# 309

# %%
len(set(df.MEASURES_NAME))
# Out:
# 1

# %%
df.columns
# Out:
# Index(['DATE', 'DATE_NAME', 'DATE_CODE', 'DATE_TYPE', 'DATE_TYPECODE',
#        'DATE_SORTORDER', 'GEOGRAPHY', 'GEOGRAPHY_NAME', 'GEOGRAPHY_CODE',
#        'GEOGRAPHY_TYPE', 'GEOGRAPHY_TYPECODE', 'GEOGRAPHY_SORTORDER', 'ITEM',
#        'ITEM_NAME', 'ITEM_CODE', 'ITEM_TYPE', 'ITEM_TYPECODE',
#        'ITEM_SORTORDER', 'MEASURES', 'MEASURES_NAME', 'OBS_VALUE',
#        'OBS_STATUS', 'OBS_STATUS_NAME', 'OBS_CONF', 'OBS_CONF_NAME', 'URN',
#        'RECORD_OFFSET', 'RECORD_COUNT'],
#       dtype='object')
